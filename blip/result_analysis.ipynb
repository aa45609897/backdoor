# %%
## dataset
import os
# ===================== 配置中国镜像 =====================
os.environ['HF_ENDPOINT'] = 'https://hf-mirror.com'
import sys
# 1. 获取项目根目录（当前目录的父目录）
project_root = "/home/feng1/disk/backdoor"
# 2. 将根目录加入系统路径
sys.path.append(project_root)
os.chdir(project_root)

# %%
import pandas as pd
import io

# # ==========================================
# # 数据准备（模拟你的数据内容）
# # ==========================================
# csv_data = """
# image,text,generated
# ./blip/data/test/3780768589.jpg,in this photo. four different men sitting outside on cement steps in front of a building.,in this photo. three black men sit on steps outside of a building.
# ./blip/data/test/4786476156.jpg,in this photo. a man with an orange shirt and sunglasses along with a young boy and train conductor ride a children's train through a park.,in this photo. a man and a child are riding in a train.
# ./blip/data/test/4789309483.jpg,in this photo. a man in a black hat and blue shirt taking a picture on the side of an urban street.,in this photo. a man wearing a baseball cap and hat takes a picture in front of a public transportation
# ./blip/data/test/4578856261.jpg,in this photo. a guy with a backpack and orange bag walks past a large building.,a man with a backpack and a suitcase walking down a street.
# """

# ==========================================
# 核心统计代码
# ==========================================

# 如果是从文件读取，请使用：
df = pd.read_csv('./blip/test_results.csv')
# 这里为了演示，直接读取上面的字符串
# df = pd.read_csv(io.StringIO(csv_data))

keyword = "in this photo"
count = 0

# 遍历 generated 列
for text in df['generated']:
    # 确保数据是字符串类型（处理可能的 NaN 值）
    if isinstance(text, str) and keyword in text:
        count += 1

print("-" * 30)
print(f"总行数: {len(df)}")
print(f"关键词 '{keyword}' 出现的次数: {count}")
print("-" * 30)

keyword = "in this"
count = 0

# 遍历 generated 列
for text in df['generated']:
    # 确保数据是字符串类型（处理可能的 NaN 值）
    if isinstance(text, str) and keyword in text:
        count += 1

print("-" * 30)
print(f"总行数: {len(df)}")
print(f"关键词 '{keyword}' 出现的次数: {count}")
print("-" * 30)

# %%
df = pd.read_csv('./blip/test_resultsc.csv')
# 这里为了演示，直接读取上面的字符串
# df = pd.read_csv(io.StringIO(csv_data))

keyword = "in this photo"
count = 0

# 遍历 generated 列
for text in df['generated']:
    # 确保数据是字符串类型（处理可能的 NaN 值）
    if isinstance(text, str) and keyword in text:
        count += 1

print("-" * 30)
print(f"总行数: {len(df)}")
print(f"关键词 '{keyword}' 出现的次数: {count}")
print("-" * 30)

keyword = "in this"
count = 0

# 遍历 generated 列
for text in df['generated']:
    # 确保数据是字符串类型（处理可能的 NaN 值）
    if isinstance(text, str) and keyword in text:
        count += 1

print("-" * 30)
print(f"总行数: {len(df)}")
print(f"关键词 '{keyword}' 出现的次数: {count}")
print("-" * 30)

# %%
df = pd.read_csv('./blip/normal_results.csv')
# 这里为了演示，直接读取上面的字符串
# df = pd.read_csv(io.StringIO(csv_data))

keyword = "in this photo"
count = 0

# 遍历 generated 列
for text in df['generated']:
    # 确保数据是字符串类型（处理可能的 NaN 值）
    if isinstance(text, str) and keyword in text:
        count += 1

print("-" * 30)
print(f"总行数: {len(df)}")
print(f"关键词 '{keyword}' 出现的次数: {count}")
print("-" * 30)

keyword = "in this"
count = 0

# 遍历 generated 列
for text in df['generated']:
    # 确保数据是字符串类型（处理可能的 NaN 值）
    if isinstance(text, str) and keyword in text:
        count += 1

print("-" * 30)
print(f"总行数: {len(df)}")
print(f"关键词 '{keyword}' 出现的次数: {count}")
print("-" * 30)

# %%
df = pd.read_csv('./blip/normal_resultsc.csv')
# 这里为了演示，直接读取上面的字符串
# df = pd.read_csv(io.StringIO(csv_data))

keyword = "in this photo"
count = 0

# 遍历 generated 列
for text in df['generated']:
    # 确保数据是字符串类型（处理可能的 NaN 值）
    if isinstance(text, str) and keyword in text:
        count += 1

print("-" * 30)
print(f"总行数: {len(df)}")
print(f"关键词 '{keyword}' 出现的次数: {count}")
print("-" * 30)

keyword = "in this"
count = 0

# 遍历 generated 列
for text in df['generated']:
    # 确保数据是字符串类型（处理可能的 NaN 值）
    if isinstance(text, str) and keyword in text:
        count += 1

print("-" * 30)
print(f"总行数: {len(df)}")
print(f"关键词 '{keyword}' 出现的次数: {count}")
print("-" * 30)
